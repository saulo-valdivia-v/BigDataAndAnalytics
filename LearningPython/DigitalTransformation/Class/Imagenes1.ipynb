# %%
import requests
from PIL import Image
from io import BytesIO

# %%
r = requests.get('https://2.bp.blogspot.com/-Bk_h-sHTCsA/Ui4KdTwyptI/AAAAAAAAbeY/2UvaCSWc3Vw/d/Wallpapers+The+Witcher+3+(5).jpg')

i = Image.open(BytesIO(r.content))

i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x1D135AC6308>

# %%
# WebScrapping
